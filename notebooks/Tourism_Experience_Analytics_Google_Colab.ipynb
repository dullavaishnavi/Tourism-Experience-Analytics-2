# %% [markdown]
# # Tourism Experience Analytics
# This notebook reproduces the data preparation and model training used by the Streamlit app.

# %%
# !pip install -q -r ../requirements.txt

# %%
from pathlib import Path
import sys
sys.path.append('../src')
from train_models import main
main()
